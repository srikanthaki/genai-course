# %%
print("Saturday is the best day of the week!")
# Out:
# Saturday is the best day of the week!

# %%
def add_numbers(a, b):
    print(a+b)
    
add_numbers(5, 10)
# Out:
# 15

# %%
try:
    lucky_number = int(input("Enter your lucky number: "))
    print(lucky_number)
except:
    print("This is not a valid number.")
# Out:
# This is not a valid number.

# %%
class Person:
    pass
p = Person()
print(p)
